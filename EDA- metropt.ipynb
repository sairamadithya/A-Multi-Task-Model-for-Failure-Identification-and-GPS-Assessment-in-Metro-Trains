# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\sairam\Downloads\metropt- labelled- mar.csv")
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            timestamp    TP2    TP3     H1  \
# 0             0     4239804  2022-03-01 00:00:00 -0.002  0.008  0.002
# 1             1     4239805  2022-03-01 00:00:01 -0.004  0.012  0.004
# 2             2     4239806  2022-03-01 00:00:02 -0.004  0.010  0.004
# 3             3     4239807  2022-03-01 00:00:03 -0.002  0.010  0.002
# 4             4     4239808  2022-03-01 00:00:04 -0.002  0.010  0.002
#
#    DV_pressure  Reservoirs  Oil_temperature  Flowmeter  ...  gpsSpeed  \
# 0       -0.026        1.73           68.775  18.844062  ...       0.0
# 1       -0.024        1.73           68.725  18.844062  ...       0.0
# 2       -0.024        1.73           68.750  18.844062  ...       0.0
# 3       -0.024        1.73           68.700  18.844062  ...       0.0
# 4       -0.022        1.73           68.725  18.834719  ...       0.0
#
#    gpsQuality  month  day  hour  minute  second  fault  location  output
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027127 entries, 0 to 2027126
# Data columns (total 31 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0.1     int64
#  1   Unnamed: 0       int64
#  2   timestamp        object
#  3   TP2              float64
#  4   TP3              float64
#  5   H1               float64
#  6   DV_pressure      float64
#  7   Reservoirs       float64
#  8   Oil_temperature  float64
#  9   Flowmeter        float64
#  10  Motor_current    float64
#  11  COMP             float64
#  12  DV_eletric       float64
#  13  Towers           float64
#  14  MPG              float64
#  15  LPS              float64
#  16  Pressure_switch  float64
#  17  Oil_level        float64
#  18  Caudal_impulses  float64
#  19  gpsLong          float64
#  20  gpsLat           float64
#  21  gpsSpeed         float64
#  22  gpsQuality       float64
#  23  month            int64
#  24  day              int64
#  25  hour             int64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# timestamp          0
# TP2                0
# TP3                0
# H1                 0
# DV_pressure        0
# Reservoirs         0
# Oil_temperature    0
# Flowmeter          0
# Motor_current      0
# COMP               0
# DV_eletric         0
# Towers             0
# MPG                0
# LPS                0
# Pressure_switch    0
# Oil_level          0
# Caudal_impulses    0
# gpsLong            0
# gpsLat             0
# gpsSpeed           0
# gpsQuality         0
# month              0
# day                0
# hour               0
# minute             0
# second             0
# fault              0
# location           0
# output             0
# dtype: int64

# %% [markdown]
# # No null values

# %%
data=data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027127 entries, 0 to 2027126
# Data columns (total 31 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0.1     int64
#  1   Unnamed: 0       int64
#  2   timestamp        object
#  3   TP2              float64
#  4   TP3              float64
#  5   H1               float64
#  6   DV_pressure      float64
#  7   Reservoirs       float64
#  8   Oil_temperature  float64
#  9   Flowmeter        float64
#  10  Motor_current    float64
#  11  COMP             float64
#  12  DV_eletric       float64
#  13  Towers           float64
#  14  MPG              float64
#  15  LPS              float64
#  16  Pressure_switch  float64
#  17  Oil_level        float64
#  18  Caudal_impulses  float64
#  19  gpsLong          float64
#  20  gpsLat           float64
#  21  gpsSpeed         float64
#  22  gpsQuality       float64
#  23  month            int64
#  24  day              int64
#  25  hour             int64
# ...

# %%
data.describe()
# Out:
#                 TP2           TP3            H1   DV_pressure    Reservoirs  \
# count  2.027127e+06  2.027127e+06  2.027127e+06  2.027127e+06  2.027127e+06
# mean   1.136294e+00  8.980022e+00  7.854466e+00 -1.915915e-02  1.610955e+00
# std    3.050617e+00  7.101330e-01  3.062239e+00  2.025520e-01  5.937546e-02
# min   -2.800000e-02  6.000000e-03 -3.000000e-02 -3.600000e-02  1.458000e+00
# 25%   -8.000000e-03  8.492000e+00  8.304000e+00 -2.800000e-02  1.592000e+00
# 50%   -6.000000e-03  9.002000e+00  8.862000e+00 -2.600000e-02  1.606000e+00
# 75%   -4.000000e-03  9.498000e+00  9.418000e+00 -2.600000e-02  1.640000e+00
# max    1.084400e+01  1.040800e+01  1.041400e+01  8.326000e+00  2.054000e+00
#
#        Oil_temperature     Flowmeter  Motor_current          COMP  \
# count     2.027127e+06  2.027127e+06   2.027127e+06  2.027127e+06
# mean      6.844108e+01  2.034899e+01   2.338710e+00  8.720643e-01
# std       5.351036e+00  3.805954e+00   2.196189e+00  3.340183e-01
# ...

# %% [markdown]
# # Same number of rows, hence no duplicate values

# %%
data=data.drop(['Unnamed: 0.1','Unnamed: 0','timestamp'],axis=1)

# %%
df_0=data[data['output']==0]
df_1=data[data['output']==1]
df_3=data[data['output']==3]

# %%
corr_matrix = df_3.corr()
plt.figure(figsize=(20, 10)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr_matrix = df_1.corr()
plt.figure(figsize=(20, 10)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
corr_matrix = df_0.corr()
plt.figure(figsize=(20, 10)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.boxplot(df['TP3'])
# Out:
# C:\Users\sairam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='TP3'>

# %%
sns.boxplot(df['Motor_current'])
# Out:
# C:\Users\sairam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Motor_current'>

# %%
sns.jointplot(data=df,x='TP2',y='TP3',hue='output')

# %%
df = pd.DataFrame(df_3)
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
g = sns.jointplot(x="H1", y="TP2", data=df_3, kind="scatter", color='blue')
g.set_axis_labels("H1", "TP2")
plt.subplots_adjust(top=0.9)
g.fig.suptitle("Scatterplot with Histograms: H1 vs. TP2")

plt.show()

# %%
df = pd.DataFrame(df_1)
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
g = sns.jointplot(x="H1", y="TP2", data=df_1, kind="scatter", color='blue')
g.set_axis_labels("H1", "TP2")
plt.subplots_adjust(top=0.9)
g.fig.suptitle("Scatterplot with Histograms: H1 vs. TP2")

plt.show()

# %%
df = pd.DataFrame(df_0)
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
g = sns.jointplot(x="H1", y="TP2", data=df_0, kind="scatter", color='blue')
g.set_axis_labels("H1", "TP2")
plt.subplots_adjust(top=0.9)
g.fig.suptitle("Scatterplot with Histograms: H1 vs. TP2")

plt.show()
